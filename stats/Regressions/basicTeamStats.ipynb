# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\cguid\AppData\Local\Temp\ipykernel_5528\555797462.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
basic_team_stats = pd.read_csv("TeamStatistics2000.csv")
basic_team_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 38 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   68 non-null     int64
#  1   School       68 non-null     object
#  2   G            68 non-null     int64
#  3   W            68 non-null     int64
#  4   L            68 non-null     int64
#  5   W-L%         68 non-null     float64
#  6   SRS          68 non-null     float64
#  7   SOS          68 non-null     float64
#  8   Unnamed: 8   0 non-null      float64
#  9   W.1          68 non-null     int64
#  10  L.1          68 non-null     int64
#  11  Unnamed: 11  0 non-null      float64
#  12  W.2          68 non-null     int64
#  13  L.2          68 non-null     int64
#  14  Unnamed: 14  0 non-null      float64
#  15  W.3          68 non-null     int64
#  16  L.3          68 non-null     int64
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
basic_team_stats.describe()
# Out:
#        Unnamed: 0          G          W          L       W-L%        SRS  \
# count    68.00000  68.000000  68.000000  68.000000  68.000000  68.000000
# mean     33.50000  35.235294  25.058824  10.176471   0.709662  11.211912
# std      19.77372   1.487436   3.939400   3.236643   0.095069   7.783501
# min       0.00000  32.000000  14.000000   4.000000   0.400000 -10.560000
# 25%      16.75000  34.000000  22.000000   8.000000   0.638250   7.590000
# 50%      33.50000  35.000000  25.000000  10.000000   0.714000  13.720000
# 75%      50.25000  36.000000  27.250000  13.000000   0.771000  15.860000
# max      67.00000  39.000000  35.000000  21.000000   0.897000  23.190000
#
#              SOS  Unnamed: 8        W.1        L.1  ...          FT  \
# count  68.000000         0.0  68.000000  68.000000  ...   68.000000
# mean    4.472794         NaN  13.029412   5.500000  ...  487.382353
# std     5.712000         NaN   2.682005   2.701575  ...   65.420803
# ...

# %%
x = basic_team_stats['W']
y = basic_team_stats['BLK']
plt.scatter(x , y)
plt.show()
